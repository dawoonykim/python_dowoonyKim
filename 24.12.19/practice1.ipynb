# %%
import folium

# %%
m = folium.Map(location=[37.547631, 126.942463], zoom_start=15,
               tiles="cartodbpositron")
folium.Marker([37.547631, 126.942463], popup="팝업", tooltip="툴팁", icon=folium.Icon(
    color="black", icon="fa-solid fa-subway")).add_to(m)

folium.Marker([37.53959008903884, 126.94590610865076], popup="subway", tooltip="마포역", icon=folium.Icon(
    color="lightblue", icon="fa-solid fa-marker", prefix="fa-solid")).add_to(m)
m

# %%
m = folium.Map(location=[37.547631, 126.942463], zoom_start=15,
               tiles="cartodbpositron")
folium.Marker([37.547631, 126.942463], popup="팝업", tooltip="툴팁", icon=folium.Icon(
    color="black", icon="fa-solid fa-subway", prefix="fa-solid")).add_to(m)

folium.Marker([37.53959008903884, 126.94590610865076], popup="subway", tooltip="마포역", icon=folium.Icon(
    color="lightblue", icon="fa-solid fa-marker", prefix="fa-solid")).add_to(m)
m.add_child(folium.ClickForMarker(popup="내가 클릭한 곳"))
m

# %%
m = folium.Map(location=[37.547631, 126.942463], zoom_start=15,
               tiles="cartodbpositron")
folium.Marker([37.547631, 126.942463], popup="팝업", tooltip="툴팁", icon=folium.Icon(
    color="black", icon="fa-solid fa-subway", prefix="fa-solid")).add_to(m)

folium.Marker([37.53959008903884, 126.94590610865076], popup="subway", tooltip="마포역", icon=folium.Icon(
    color="lightblue", icon="fa-solid fa-marker", prefix="fa-solid")).add_to(m)
m.add_child(folium.ClickForMarker(popup="내가 클릭한 곳"))
m.add_child(folium.LatLngPopup())
m

# %%
m = folium.Map(location=[37.3141,127.0929], zoom_start=15,
               tiles="cartodbpositron")
folium.Marker([37.3141,127.0929], popup="우리집", tooltip="우리집", icon=folium.Icon(
    color="black", icon="fa-solid fa-marker", prefix="fa-solid")).add_to(m)

folium.Marker([37.53959008903884, 126.94590610865076], popup="subway", tooltip="마포역", icon=folium.Icon(
    color="lightblue", icon="fa-solid fa-subway", prefix="fa-solid")).add_to(m)
m.add_child(folium.ClickForMarker(popup="내가 클릭한 곳"))
m.add_child(folium.LatLngPopup())
folium.Circle()
folium.CircleMarker([37.3141,127.0929],radius=100,color="#ffffff",fill_color="#00ff00", popup="CircleMarker").add_to(m)
folium.Circle([37.3141,127.0929],radius=100,color="#eb9e34",popup="Circle",tooltip="tooltip").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d23af3788161cfc15eb8691e20b492f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d23af3788161cfc15eb8691e20b492f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d23af3788161cfc15eb8691e20b492f2 = L.map(
#                 &quot;map_d23af3788161cfc15eb8691e20b492f2&quot;,
#                 {
#                     center: [37.3141, 127.0929],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48c8e073973330b88728b70c0a934656 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48c8e073973330b88728b70c0a934656.addTo(map_d23af3788161cfc15eb8691e20b492f2);
#
#
#             var marker_16356c4e52b30467b7795fa4adcbd3e9 = L.marker(
#                 [37.3141, 127.0929],
#                 {
# }
#             ).addTo(map_d23af3788161cfc15eb8691e20b492f2);
#
#
#             var icon_712e3a002e4d46a73536e8f015f091ad = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-marker&quot;,
#   &quot;prefix&quot;: &quot;fa-solid&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_16356c4e52b30467b7795fa4adcbd3e9.setIcon(icon_712e3a002e4d46a73536e8f015f091ad);
#
#
#         var popup_9caa5770a37490a17c3c671930ed6e9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7b48481d9bfe58eceacbe625043d876 = $(`&lt;div id=&quot;html_e7b48481d9bfe58eceacbe625043d876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;우리집&lt;/div&gt;`)[0];
#                 popup_9caa5770a37490a17c3c671930ed6e9d.setContent(html_e7b48481d9bfe58eceacbe625043d876);
#
#
#
#         marker_16356c4e52b30467b7795fa4adcbd3e9.bindPopup(popup_9caa5770a37490a17c3c671930ed6e9d)
#         ;
#
#
#
#
#             marker_16356c4e52b30467b7795fa4adcbd3e9.bindTooltip(
#                 `&lt;div&gt;
#                      우리집
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ddbc92b965b7d6f428fe99e01be9ec7e = L.marker(
#                 [37.53959008903884, 126.94590610865076],
#                 {
# }
#             ).addTo(map_d23af3788161cfc15eb8691e20b492f2);
#
#
#             var icon_494d123e5aa8c0716b942d7539629a35 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-subway&quot;,
#   &quot;prefix&quot;: &quot;fa-solid&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_ddbc92b965b7d6f428fe99e01be9ec7e.setIcon(icon_494d123e5aa8c0716b942d7539629a35);
#
#
#         var popup_c1c6c07b5a86eacac41a815f94eb127b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27d214f4cc79a08414f4270e0865dcc1 = $(`&lt;div id=&quot;html_27d214f4cc79a08414f4270e0865dcc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_c1c6c07b5a86eacac41a815f94eb127b.setContent(html_27d214f4cc79a08414f4270e0865dcc1);
#
#
#
#         marker_ddbc92b965b7d6f428fe99e01be9ec7e.bindPopup(popup_c1c6c07b5a86eacac41a815f94eb127b)
#         ;
#
#
#
#
#             marker_ddbc92b965b7d6f428fe99e01be9ec7e.bindTooltip(
#                 `&lt;div&gt;
#                      마포역
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_d23af3788161cfc15eb8691e20b492f2);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_d23af3788161cfc15eb8691e20b492f2.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(`내가 클릭한 곳`);
#                     };
#                 map_d23af3788161cfc15eb8691e20b492f2.on(&#x27;click&#x27;, newMarker);
#
#
#                 var lat_lng_popup_ad052bb2ba887464c54a9369e4168991 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_ad052bb2ba887464c54a9369e4168991
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.ln
