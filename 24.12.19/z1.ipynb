# %%
import folium

# %%
m = folium.Map(location=[37.3141, 127.0929], zoom_start=15)
m = m.get_root()
m.width = 800
m.height = 600

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location=[37.3141, 127.0929],
               zoom_start=15, tiles="cartodbpositron")

m = m.get_root()
m.width = 800
m.height = 600

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location=[37.3141, 127.0929], zoom_start=15)
folium.Marker([37.3141, 127.0929], popup="우리집", tooltip="집에가고싶다").add_to(m)
m = m.get_root()
m.width = 800
m.height = 600

m

# %%
m = folium.Map(location=[37.3141, 127.0929], zoom_start=15)
folium.Marker([37.3141, 127.0929], popup="집에가고싶다", tooltip="우리집").add_to(m)
folium.Marker([37.32438596601063, 127.10797438847524],
              popup="죽전역", tooltip="Subway").add_to(m)
m = m.get_root()
m.width = 800
m.height = 600

m

# %%
m = folium.Map(location=[37.3141, 127.0929], zoom_start=15)
folium.Marker([37.3141, 127.0929], popup="집에가고싶다", tooltip="우리집").add_to(m)
# folium.Marker([37.32438596601063,127.10797438847524], popup="죽전역", tooltip="Subway").add_to(m)
folium.Marker([37.32438596601063, 127.10797438847524], popup="죽전역", tooltip="Subway", icon=folium.Icon(
    color="black", icon="fa-solid fa-train-subway", prefix="fa-solid")).add_to(m)
m = m.get_root()
m.width = 800
m.height = 600

m

# %%
m = folium.Map(location=[37.3141, 127.0929], zoom_start=15)
folium.Marker([37.3141, 127.0929], popup="집에가고싶다", tooltip="우리집").add_to(m)
# folium.Marker([37.32438596601063,127.10797438847524], popup="죽전역", tooltip="Subway").add_to(m)
folium.Marker([37.32438596601063, 127.10797438847524], popup="죽전역", tooltip="Subway", icon=folium.Icon(
    color="black", icon="fa-solid fa-train-subway", prefix="fa-solid")).add_to(m)
m.add_child(folium.ClickForMarker(popup="내가 클릭한 곳"))
m = m.get_root()
m.width = 800
m.height = 600

m

# %%
m = folium.Map(location=[37.3141, 127.0929], zoom_start=15)
folium.Marker([37.3141, 127.0929], popup="집에가고싶다", tooltip="우리집").add_to(m)
# folium.Marker([37.3248,127.10797438847524], popup="죽전역", tooltip="Subway").add_to(m)
folium.Marker([37.3248, 127.1074], popup="죽전역", tooltip="Subway", icon=folium.Icon(
    color="black", icon="fa-solid fa-train-subway", prefix="fa-solid")).add_to(m)
m.add_child(folium.ClickForMarker(popup="내가 클릭한 곳"))
m.add_child(folium.LatLngPopup())
m = m.get_root()
m.width = 800
m.height = 600

m

# %%
m = folium.Map(location=[37.3141, 127.0929], zoom_start=15)
folium.Marker([37.3141, 127.0929], popup="집에가고싶다", tooltip="우리집").add_to(m)
# folium.Marker([37.3248,127.10797438847524], popup="죽전역", tooltip="Subway").add_to(m)
folium.Marker([37.3248, 127.1074], popup="죽전역", tooltip="Subway", icon=folium.Icon(
    color="black", icon="fa-solid fa-train-subway", prefix="fa-solid")).add_to(m)
m.add_child(folium.ClickForMarker(popup="내가 클릭한 곳"))
m.add_child(folium.LatLngPopup())

folium.CircleMarker([37.3141, 127.0929], radius=100, color="blue",
                    fill_color="white", popup="CircleMarker", tooltip="tooltip").add_to(m)
folium.Circle([37.3248, 127.1074], radius=100, color="green",
              fill_color="black", popup="Cirlce", tooltip="tooltip").add_to(m)
m = m.get_root()
m.width = 800
m.height = 600

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
