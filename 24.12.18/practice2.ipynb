# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(3)
y=[100,400,900]

# %%
plt.bar(x, y, color=["r", "g", "b"], width=0.6)
# Out:
# <BarContainer object of 3 artists>

# %%
# plt.bar(x, y, color=["r", "g", "b"], width=0.6)
plt.plot(x,y)
plt.xticks(x,["2018","2019","2020"])
plt.show()

# %%
y1=np.arange(3)
x1=[100,400,900]

# %%
# plt.bar(y1, x1, color=["r", "g", "b"], width=0.6)
plt.barh(y1,x1,color=["r","g","b"],height=0.7)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(y1,x1,color=["r","g","b"],height=0.6)
# plt.plot(x1,y1)
print(y1,x1)
plt.yticks(y1,["2018","2019","2020"])
plt.show()
# Out:
# [0 1 2] [100, 400, 900]

# %%
n = 50
x = np.random.rand(n)
y = np.random.rand(n)
plt.plot(x, y)

area = (30*np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors, cmap="Spectral", alpha=0.5)
plt.show()

# %%
n = 50
x = [0,1,2]
y = [0,1,2]

plt.plot(x,y)

area = [1000,1000,1000]

plt.scatter(x, y, s=area, cmap="Spectral", alpha=0.5)
plt.show()
# Out:
# C:\Users\dawoo\AppData\Local\Temp\ipykernel_25756\1924119830.py:9: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, s=area, cmap="Spectral", alpha=0.5)

# %%
ratio = [34, 32, 16, 18]
labels = ["Apple", "Banana", "Melon", "Grapes"]
wedgeprops = {"width": 0.7, "edgecolor": "k", "linewidth": 1}
# wedgeprops = {"width": 0.7, "edgecolor": "k", "linewidth": 1}
plt.pie(ratio, labels=labels, autopct="%.1f%%", explode=[0, 0.1, 0, 0.1], colors=["red", "yellow", "green", "purple"], wedgeprops=wedgeprops)
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ["Apple", "Banana", "Melon", "Grapes"]
wedgeprops = {"width": 0.7, "edgecolor": "k", "linewidth": 1}
# wedgeprops = {"width": 0.7, "edgecolor": "k", "linewidth": 1}
plt.pie(ratio, labels=labels, autopct="%.1f%%", explode=[0, 0.1, 0, 0.1], colors=[
        "red", "yellow", "green", "purple"], wedgeprops=wedgeprops, counterclock=False)
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ["Apple", "Banana", "Melon", "Grapes"]
wedgeprops = {"width": 0.7, "edgecolor": "k", "linewidth": 1}
# wedgeprops = {"width": 0.7, "edgecolor": "k", "linewidth": 1}
plt.pie(ratio, labels=labels, autopct="%.1f%%", explode=[0, 0.1, 0, 0.1], colors=[
        "red", "yellow", "green", "purple"], wedgeprops=wedgeprops, counterclock=False,startangle=90)
plt.show()
